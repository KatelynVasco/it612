# %% [markdown]
# <a href="https://colab.research.google.com/github/KatelynVasco/it612/blob/main/Participation_JS%20Activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile code.js
#
# function addTax(price, rate) {
#   return price * (1 + rate);
# }
#
# function createBurner(secret, limit) {
#   return function(limit) {
#     if (limit < limit) {
#       return secret;
#     }
# }
# Out:
# Overwriting code.js
